# %% [markdown]
# ## Lab02 : Medical Insurance Exploratory Data Analysis
# ### Name :

# %% [markdown]
# Why do we need visualization ?
# - for creating dashboard "telling a story about something"
# - for exploratory data analysis EDA

# %% [markdown]
# In our course we will focus more about EDA

# %% [markdown]
# We wil use our previous data medical insurance dataset that descripe where people are always confused about their medical insurance and don't know the cost of insurance at different ages and conditions. This data is useful for these people and is useful to make predictions of the insurance cost they will have to pay
# in that lab our task is to do some visualization and use these visualization to get more insights and information about our data

# %% [markdown]
# <font size = 5  color = 'red'>What is Exploratory Data Analysis?</font><br>
# Exploratory data analysis EDA is a set of visualization techniques and others that helps to get fully understanding of data and draw attention to the most important features, detect anomalies and reveal the structure of each feature During exploring, you should look at your data from as many angles as possible since the devil is always in the details

# %% [markdown]
# for visualization there are many python libraries like matplotlib , seaborn but both these libraries have it's own limitation but there is a comman limitation which is interaction fo that we will use plotly as it support interaction

# %% [markdown]
# <font size = 6>Libraries</font><br>
# <font size = 2 color = 'gray'>just run that cell</font>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Train_Data.csv")
data.head()
# Out:
#          age     sex        bmi smoker     region  children       charges
# 0  21.000000    male  25.745000     no  northeast         2   3279.868550
# 1  36.976978  female  25.744165    yes  southeast         3  21454.494239
# 2  18.000000    male  30.030000     no  southeast         1   1720.353700
# 3  37.000000    male  30.676891     no  northeast         3   6801.437542
# 4  58.000000    male  32.010000     no  southeast         1  11946.625900

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# **Q:** Write a Python code to visualize Ratio between Males and Females using :
#
# - Pie Chart
# - Countplot

# %%
sex_wrapper = {0:'male', 1:'female'}
data['keys'] = data.sex.replace(sex_wrapper)

# %%
plt.pie(data['sex'].value_counts() ,autopct='%1.0f%%',labels=['male','female'])
plt.show()

# %%
sns.countplot(x = data['keys'] )
plt.show()

# %%
data
# Out:
#       age  sex        bmi  smoker     region  children       charges    keys
# 0      21    0  25.745000       0  northeast         2   3279.868550    male
# 1      37    1  25.744165       1  southeast         3  21454.494240  female
# 2      18    0  30.030000       0  southeast         1   1720.353700    male
# 3      37    0  30.676891       0  northeast         3   6801.437542    male
# 4      58    0  32.010000       0  southeast         1  11946.625900    male
# ...   ...  ...        ...     ...        ...       ...           ...     ...
# 3625   49    1  41.426984       0  northwest         4  10987.324960  female
# 3626   39    1  26.202557       0  southeast         2  11735.844350  female
# 3627   56    0  40.300000       0  southwest         0  10602.385000    male
# 3628   48    1  34.930624       0  southeast         1   8976.140452  female
# 3629   38    1  25.219233       0  northeast         3   7027.698968  female
#
# [3630 rows x 8 columns]

# %%
data.region.value_counts()
# Out:
# region
# southeast    1021
# northwest     911
# southwest     850
# northeast     848
# Name: count, dtype: int64

# %%
colors = ['steelblue','pink']
data.groupby(['sex']).count().plot.pie(y='keys',autopct='%1.0f%%', colors = colors,figsize=(5, 5))
# Out:
# <Axes: ylabel='keys'>

# %% [markdown]
# **Q:** Write a Python code to visualize Ratio between Smokers and NotSmokers using :
#
# - Pie Chart
# - Countplot

# %%
# Pie Chart
plt.pie(data['smoker'].value_counts() ,autopct='%1.0f%%',labels=['no','yes'],)
plt.show()

# %%
sex_wrapper = {0:'no', 1:'yes'}
data['smoker_keys'] = data.smoker.replace(sex_wrapper)

# %%
data
# Out:
#       age  sex        bmi  smoker     region  children       charges    keys  \
# 0      21    0  25.745000       0  northeast         2   3279.868550    male
# 1      37    1  25.744165       1  southeast         3  21454.494240  female
# 2      18    0  30.030000       0  southeast         1   1720.353700    male
# 3      37    0  30.676891       0  northeast         3   6801.437542    male
# 4      58    0  32.010000       0  southeast         1  11946.625900    male
# ...   ...  ...        ...     ...        ...       ...           ...     ...
# 3625   49    1  41.426984       0  northwest         4  10987.324960  female
# 3626   39    1  26.202557       0  southeast         2  11735.844350  female
# 3627   56    0  40.300000       0  southwest         0  10602.385000    male
# 3628   48    1  34.930624       0  southeast         1   8976.140452  female
# 3629   38    1  25.219233       0  northeast         3   7027.698968  female
#
#      smoker_keys
# 0             no
# ...

# %%
# Countplot
sns.countplot(x = data['smoker_keys'] ,palette=colors  )
# Out:
# <Axes: xlabel='smoker_keys', ylabel='count'>

# %% [markdown]
# **Q:** Write a Python code to visualize Ratio between Regions using :
#
# - Pie Chart
# - Countplot

# %%
# Pie Chart

plt.pie(data['region'].value_counts() ,labels=['southeast','northwest','southwest','northeast'],autopct='%1.0f%%',colors = colors)
plt.show()

# %%
# Countplot
sns.countplot(x = data['region'] , palette=colors)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# <font color = 'blue'>Why Pie Chart is not the best choice?</font><br>
# <font size = 2 color = 'gray'>double click to edit cell</font><br>
# <font color='blue'>Answer</font><br>

# %% [markdown]
# 1.   Pie charts are not well-suited for comparing multiple sets of data
# 2.   When there are many categories, pie charts become cluttered with labels and can be difficult to read
#
# 3.   Pie charts do not provide precise numerical information

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x=data['age'])
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# **Q:** Write a Python code to plot **Box Chart** of **BMI** using **plotly** and another time using **seaborn**

# %%
# Seaborn
sns.boxplot(x=data['bmi'])
# Out:
# <Axes: xlabel='bmi'>

# %%
# Plotly
plt.boxplot(data['bmi'])
plt.title('Box Plot using plotly')
plt.ylabel( 'BMI')
plt.show()

# %% [markdown]
# **Q:** Write a Python function to calculate IQR of a given feature

# %%
def IQR(x):
    q2 =len(x)//2
    q3,q1 =q2 + (len(x) - q2 ) // 2 ,q2//2
    iqr = q3 - q1
    return iqr

# %%
iqr = IQR(data['age'])
print("Inter Quartile Rang of Age = ",iqr)
# Out:
# Inter Quartile Rang of Age =  1815

# %% [markdown]
# Box plot gives more intuation like median, max value & min value (exclude outliers)
# but we still want to interpret data distribution

# %% [markdown]
# #### Histogram

# %%
sns.histplot(data['charges'])
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
g=sns.histplot(data['charges'],bins=30, kde=True)
g.lines[0].set_color('black')
g.axvline(x=data['charges'].mean(), color='b', label='Mean', linestyle='--', linewidth=2)
g.axvline(x=data['charges'].median(), color='g', label='Median', linestyle='--', linewidth=2)

# %% [markdown]
# from the previous graph , **charges** is positively or negatively skewed?<br>
# <font size = 2 color = 'gray'>double click to edit cell</font><br>
# <font color='blue'>Answer</font><br>

# %% [markdown]
# **Q:** Write a Python code to plot distribution of **BMI** and **Age** and define for both if they are normaly distributed,positively or negatively skewed?

# %% [markdown]
# **Distibution** **of** **BMI** **is** **normally** **distributed**

# %%
# Distibution of BMI is normally disttibuted
g=sns.histplot(data['bmi'],bins=30, kde=True)
g.lines[0].set_color('black')
g.axvline(x=data['bmi'].mean(), color='b', label='Mean', linestyle='--', linewidth=2)
g.axvline(x=data['bmi'].median(), color='g', label='Median', linestyle='--', linewidth=2)

# %% [markdown]
# **Distibution** **of** **age** **is** **multimodal** **distributed**

# %%
# Age
g=sns.histplot(data['age'],bins=30, kde=True)
g.lines[0].set_color('black')
g.axvline(x=data['age'].mean(), color='b', label='Mean', linestyle='--', linewidth=2)
g.axvline(x=data['age'].median(), color='g', label='Median', linestyle='--', linewidth=2)

# %% [markdown]
# Relations Between distinct features

# %% [markdown]
# What do you notice from that chart?

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='smoker', y='children', hue='age')
plt.title('Relation between Age and Charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='age', y='charges', hue='age')
plt.title('Relation between Age and Charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# **Q:** Write a Python code to plot relation between **Region** and **Charges**.

# %%
# keep in mind that region lies on y axis and shape of each region differ from one to another
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='charges', y='region', hue='region')
plt.title('Relation between Region and Charges')
plt.xlabel('Charges')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# **Q:** Write a Python code to plot relation between **Region** and **Charges** and **Smoker**.

# %%
# keep in mind that region lies on y axis and shape of smoker
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='charges', y='region',style='smoker', hue='smoker')
plt.title('Relation between Region and Charges')
plt.xlabel('Charges')
plt.ylabel('Region')
plt.show()

# %%
# keep in mind that region lies on y axis and shape of smoker
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='bmi', y='charges',style='smoker', hue='smoker')
plt.title('Relation between bmi and charges and smoker')
plt.xlabel('bmi')
plt.ylabel('charges')
plt.show()

# %%
def countingSort(array):
    size = len(array)
    output = [0] * size

    # Initialize count array
    count = [0] * 10

    # Store the count of each elements in count array
    for i in range(0, size):
        count[array[i]] += 1

    # Store the cummulative count
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Find the index of each element of the original array in count array
    # place the elements in output array
    i = size - 1
    while i >= 0:
        output[count[array[i]] - 1] = array[i]
        count[array[i]] -= 1
        i -= 1

    # Copy the sorted elements into original array
    for i in range(0, size):
        array[i] = output[i]


data = [4, 2, 2, 8, 3, 3, 1]
countingSort(data)
print("Sorted Array in Ascending Order: ")
print(data)
# Out:
# Sorted Array in Ascending Order:
# [1, 2, 2, 3, 3, 4, 8]

# %%
data = [4, 2, 2, 8, 3, 3, 1]
data.sort()

# %%
data
# Out:
# [1, 2, 2, 3, 3, 4, 8]

# %%
max(data)
# Out:
# 8

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'caesarCipher' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING s
#  2. INTEGER k
#

def caesarCipher(s, k):
    origAlph ='abcdefghijklmnopqrstuvwxyz'
    AlphRot = origAlph[k:] + origAlph[:k]
    listOrigAlph=list(origAlph)
    listAlphRot=list(AlphRot)
    result=list()
    for i in s:
      if i.lower() in origAlph:
        result.append(listAlphRot[s.index(i.lower())])
      else:
          continue
    return "".join(result)

if __name__ == '__main__':

    n = int(input().strip())

    s = input()

    k = int(input().strip())

    result = caesarCipher(s, k)
    print(result)
# Out:
# 11
# middle-Outz
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0e9508d95161> in <cell line: 31>()
#      37     k = int(input().strip())
#      38
# ---> 39     result = caesarCipher(s, k)
#      40     print(result)
#
# <ipython-input-2-0e9508d95161> in caesarCipher(s, k)
#      24     for i in s:
#      25       if i.lower() in origAlph:
# ---> 26         result.append(listAlphRot[s.index(i.lower())])
#      27       else:
#      28           continue
#
# ValueError: substring not found

# %%
s="cdef"
origAlph ='abcdefghijklmnopqrstuvwxyz'
AlphRot = origAlph[k:] + origAlph[:k]
listOrigAlph=list(origAlph)
listAlphRot=list(AlphRot)
result=list()
for i in s:
   if i.lower() in origAlph:
     result.append(listAlphRot[listOrigAlph.index(i.lower())])

# %%
result
# Out:
# ['e', 'f', 'g', 'h']

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'caesarCipher' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING s
#  2. INTEGER k
#

def caesarCipher(s, k):
    while(k>26):
      k-=26
    origAlph ='abcdefghijklmnopqrstuvwxyz'
    AlphRot = origAlph[k:] + origAlph[:k]
    listOrigAlph=list(origAlph)
    listAlphRot=list(AlphRot)
    result=list()


    for i in s:
     if i.isupper():
      result.append(listAlphRot[listOrigAlph.index(i.lower())].capitalize())

     else:
      if i in origAlph:
          result.append(listAlphRot[listOrigAlph.index(i)])
      else:
          result.append(i)
    return ''.join(result)


if __name__ == '__main__':

    n = int(input().strip())

    s = input()

    k = int(input().strip())

    result = caesarCipher(s, k)

    print (result)
# Out:
# 10
# 159357lcfd
# 98
# 159357fwzx

# %%
47www.abc.xy
